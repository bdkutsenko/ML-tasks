# %% [markdown]
# # Задание 2.1 - Нейронные сети
#
# В этом задании вы реализуете и натренируете настоящую нейроную сеть своими руками!
#
# В некотором смысле это будет расширением прошлого задания - нам нужно просто составить несколько линейных классификаторов вместе!
#
# <img src="https://i.redd.it/n9fgba8b0qr01.png" alt="Stack_more_layers" width="400px"/>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from google.colab import drive
drive.mount('/content/drive')
import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/assignment2')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from dataset import load_svhn, random_split_train_val
from gradient_check import check_layer_gradient, check_layer_param_gradient, check_model_gradient
from layers import FullyConnectedLayer, ReLULayer
from model import TwoLayerNet
from trainer import Trainer, Dataset
from optim import SGD, MomentumSGD
from metrics import multiclass_accuracy

# %% [markdown]
# # Загружаем данные
#
# И разделяем их на training и validation.

# %%
def prepare_for_neural_network(train_X, test_X):
    train_flat = train_X.reshape(train_X.shape[0], -1).astype(np.float) / 255.0
    test_flat = test_X.reshape(test_X.shape[0], -1).astype(np.float) / 255.0
    
    # Subtract mean
    mean_image = np.mean(train_flat, axis = 0)
    train_flat -= mean_image
    test_flat -= mean_image
    
    return train_flat, test_flat
    
train_X, train_y, test_X, test_y = load_svhn("/content/drive/MyDrive/Colab Notebooks/assignment1/data", max_train=10000, max_test=1000)    
train_X, test_X = prepare_for_neural_network(train_X, test_X)
# Split train into train and val
train_X, train_y, val_X, val_y = random_split_train_val(train_X, train_y, num_val = 1000)

# %% [markdown]
# # Как всегда, начинаем с кирпичиков
#
# Мы будем реализовывать необходимые нам слои по очереди. Каждый слой должен реализовать:
# - прямой проход (forward pass), который генерирует выход слоя по входу и запоминает необходимые данные
# - обратный проход (backward pass), который получает градиент по выходу слоя и вычисляет градиент по входу и по параметрам
#
# Начнем с ReLU, у которого параметров нет.

# %%
# DONE: Implement ReLULayer layer in layers.py
# Note: you'll need to copy implementation of the gradient_check function from the previous assignment

X = np.array([[1,-2,3],
              [-1, 2, 0.1]
              ])

assert check_layer_gradient(ReLULayer(), X)
# Out:
# Gradient check passed!

# %% [markdown]
# А теперь реализуем полносвязный слой (fully connected layer), у которого будет два массива параметров: W (weights) и B (bias).
#
# Все параметры наши слои будут использовать для параметров специальный класс `Param`, в котором будут храниться значения параметров и градиенты этих параметров, вычисляемые во время обратного прохода.
#
# Это даст возможность аккумулировать (суммировать) градиенты из разных частей функции потерь, например, из cross-entropy loss и regularization loss.

# %%
# DONE: Implement FullyConnected layer forward and backward methods
assert check_layer_gradient(FullyConnectedLayer(3, 4), X)
# DONE: Implement storing gradients for W and B
assert check_layer_param_gradient(FullyConnectedLayer(3, 4), X, 'W')
assert check_layer_param_gradient(FullyConnectedLayer(3, 4), X, 'B')
# Out:
# Gradient check passed!
# Gradient check passed!
# Gradient check passed!

# %% [markdown]
# ## Создаем нейронную сеть
#
# Теперь мы реализуем простейшую нейронную сеть с двумя полносвязным слоями и нелинейностью ReLU. Реализуйте функцию `compute_loss_and_gradients`, она должна запустить прямой и обратный проход через оба слоя для вычисления градиентов.
#
# Не забудьте реализовать очистку градиентов в начале функции.

# %%
# DONE: In model.py, implement compute_loss_and_gradients function
model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 3, reg = 0)
loss = model.compute_loss_and_gradients(train_X[:2], train_y[:2])

# DONE Now implement backward pass and aggregate all of the params
check_model_gradient(model, train_X[:2], train_y[:2])
# Out:
# Checking gradient for W1
# Gradient check passed!
# Checking gradient for B1
# Gradient check passed!
# Checking gradient for W2
# Gradient check passed!
# Checking gradient for B2
# Gradient check passed!
# True

# %% [markdown]
# Теперь добавьте к модели регуляризацию - она должна прибавляться к loss и делать свой вклад в градиенты.

# %%
# DONE Now implement l2 regularization in the forward and backward pass
model_with_reg = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 3, reg = 1e1)
loss_with_reg = model_with_reg.compute_loss_and_gradients(train_X[:2], train_y[:2])
assert loss_with_reg > loss and not np.isclose(loss_with_reg, loss), \
    "Loss with regularization (%2.4f) should be higher than without it (%2.4f)!" % (loss, loss_with_reg)

check_model_gradient(model_with_reg, train_X[:2], train_y[:2])
# Out:
# Checking gradient for W1
# Gradient check passed!
# Checking gradient for B1
# Gradient check passed!
# Checking gradient for W2
# Gradient check passed!
# Checking gradient for B2
# Gradient check passed!
# True

# %% [markdown]
# Также реализуем функцию предсказания (вычисления значения) модели на новых данных.
#
# Какое значение точности мы ожидаем увидеть до начала тренировки?

# %%
# Finally, implement predict function!

# DONE: Implement predict function
# What would be the value we expect?
multiclass_accuracy(model_with_reg.predict(train_X[:30]), train_y[:30])
# Out:
# 0.1

# %% [markdown]
# # Допишем код для процесса тренировки
#
# Если все реализовано корректно, значение функции ошибки должно уменьшаться с каждой эпохой, пусть и медленно. Не беспокойтесь пока про validation accuracy.

# %%
model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-2)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, SGD(), learning_rate = 1e-2)

# TODO Implement missing pieces in Trainer.fit function
# You should expect loss to go down every epoch, even if it's slow
loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 42.906639, Train accuracy: 0.360444, val accuracy: 0.360000
# Loss: 33.419862, Train accuracy: 0.568000, val accuracy: 0.561000
# Loss: 28.926326, Train accuracy: 0.550222, val accuracy: 0.532000
# Loss: 26.573948, Train accuracy: 0.636889, val accuracy: 0.613000
# Loss: 25.214199, Train accuracy: 0.661222, val accuracy: 0.617000
# Loss: 24.756061, Train accuracy: 0.669333, val accuracy: 0.623000
# Loss: 24.034542, Train accuracy: 0.704111, val accuracy: 0.657000
# Loss: 23.698323, Train accuracy: 0.724667, val accuracy: 0.667000
# Loss: 23.548258, Train accuracy: 0.737444, val accuracy: 0.694000
# Loss: 23.065216, Train accuracy: 0.715667, val accuracy: 0.643000
# Loss: 22.857902, Train accuracy: 0.719889, val accuracy: 0.683000
# Loss: 22.733188, Train accuracy: 0.766333, val accuracy: 0.687000
# Loss: 22.579646, Train accuracy: 0.734000, val accuracy: 0.654000
# Loss: 22.830973, Train accuracy: 0.764222, val accuracy: 0.704000
# Loss: 22.399686, Train accuracy: 0.751556, val accuracy: 0.691000
# Loss: 22.128527, Train accuracy: 0.763889, val accuracy: 0.688000
# Loss: 22.628770, Train accuracy: 0.774889, val accuracy: 0.702000
# Loss: 22.400591, Train accuracy: 0.787333, val accuracy: 0.696000
# Loss: 22.242055, Train accuracy: 0.803222, val accuracy: 0.723000
# Loss: 22.339672, Train accuracy: 0.789333, val accuracy: 0.706000

# %%
plt.plot(train_history)
plt.plot(val_history)

# %% [markdown]
# # Улучшаем процесс тренировки
#
# Мы реализуем несколько ключевых оптимизаций, необходимых для тренировки современных нейросетей.

# %% [markdown]
# ## Уменьшение скорости обучения (learning rate decay)
#
# Одна из необходимых оптимизаций во время тренировки нейронных сетей - постепенное уменьшение скорости обучения по мере тренировки.
#
# Один из стандартных методов - уменьшение скорости обучения (learning rate) каждые N эпох на коэффициент d (часто называемый decay). Значения N и d, как всегда, являются гиперпараметрами и должны подбираться на основе эффективности на проверочных данных (validation data).
#
# В нашем случае N будет равным 1.

# %%
# DONE Implement learning rate decay inside Trainer.fit method
# Decay should happen once per epoch

model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-1)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, SGD(), learning_rate_decay=0.99)

initial_learning_rate = trainer.learning_rate
loss_history, train_history, val_history = trainer.fit()

assert trainer.learning_rate < initial_learning_rate, "Learning rate should've been reduced"
assert trainer.learning_rate > 0.5*initial_learning_rate, "Learning rate shouldn'tve been reduced that much!"
# Out:
# Loss: 43.506198, Train accuracy: 0.324889, val accuracy: 0.341000
# Loss: 38.557154, Train accuracy: 0.533778, val accuracy: 0.538000
# Loss: 36.586377, Train accuracy: 0.477222, val accuracy: 0.470000
# Loss: 36.665235, Train accuracy: 0.593778, val accuracy: 0.590000
# Loss: 36.108652, Train accuracy: 0.575000, val accuracy: 0.569000
# Loss: 35.974985, Train accuracy: 0.492556, val accuracy: 0.489000
# Loss: 35.917096, Train accuracy: 0.589111, val accuracy: 0.606000
# Loss: 35.594951, Train accuracy: 0.592444, val accuracy: 0.576000
# Loss: 35.576340, Train accuracy: 0.599778, val accuracy: 0.595000
# Loss: 35.537845, Train accuracy: 0.614111, val accuracy: 0.594000
# Loss: 35.366290, Train accuracy: 0.532889, val accuracy: 0.551000
# Loss: 35.304539, Train accuracy: 0.669111, val accuracy: 0.657000
# Loss: 35.154149, Train accuracy: 0.564000, val accuracy: 0.545000
# Loss: 35.323405, Train accuracy: 0.591667, val accuracy: 0.585000
# Loss: 35.077233, Train accuracy: 0.610222, val accuracy: 0.605000
# Loss: 35.012995, Train accuracy: 0.615000, val accuracy: 0.605000
# Loss: 35.079376, Train accuracy: 0.579667, val accuracy: 0.576000
# Loss: 34.932374, Train accuracy: 0.651111, val accuracy: 0.641000
# Loss: 34.671862, Train accuracy: 0.607111, val accuracy: 0.600000
# Loss: 34.819556, Train accuracy: 0.628556, val accuracy: 0.623000

# %% [markdown]
# # Накопление импульса (Momentum SGD)
#
# Другой большой класс оптимизаций - использование более эффективных методов градиентного спуска. Мы реализуем один из них - накопление импульса (Momentum SGD).
#
# Этот метод хранит скорость движения, использует градиент для ее изменения на каждом шаге, и изменяет веса пропорционально значению скорости.
# (Физическая аналогия: Вместо скорости градиенты теперь будут задавать ускорение, но будет присутствовать сила трения.)
#
# ```
# velocity = momentum * velocity - learning_rate * gradient
# w = w + velocity
# ```
#
# `momentum` здесь коэффициент затухания, который тоже является гиперпараметром (к счастью, для него часто есть хорошее значение по умолчанию, типичный диапазон -- 0.8-0.99).
#
# Несколько полезных ссылок, где метод разбирается более подробно:
# http://cs231n.github.io/neural-networks-3/#sgd
# https://distill.pub/2017/momentum/

# %%
# DONE: Implement MomentumSGD.update function in optim.py

model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-2)
dataset = Dataset(train_X, train_y, val_X, val_y)
trainer = Trainer(model, dataset, MomentumSGD(), learning_rate=1e-4, learning_rate_decay=0.99)

# You should see even better results than before!
loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 45.210009, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 44.626290, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 44.512873, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 44.160290, Train accuracy: 0.196667, val accuracy: 0.206000
# Loss: 43.204796, Train accuracy: 0.222333, val accuracy: 0.227000
# Loss: 41.981045, Train accuracy: 0.271111, val accuracy: 0.269000
# Loss: 40.352725, Train accuracy: 0.299889, val accuracy: 0.308000
# Loss: 38.244326, Train accuracy: 0.355222, val accuracy: 0.348000
# Loss: 35.930882, Train accuracy: 0.407889, val accuracy: 0.404000
# Loss: 33.848743, Train accuracy: 0.454333, val accuracy: 0.441000
# Loss: 32.043239, Train accuracy: 0.496778, val accuracy: 0.490000
# Loss: 30.334531, Train accuracy: 0.529000, val accuracy: 0.527000
# Loss: 28.824570, Train accuracy: 0.561778, val accuracy: 0.540000
# Loss: 27.400928, Train accuracy: 0.589556, val accuracy: 0.577000
# Loss: 26.249403, Train accuracy: 0.615444, val accuracy: 0.600000
# Loss: 25.150102, Train accuracy: 0.638222, val accuracy: 0.637000
# Loss: 24.300990, Train accuracy: 0.639556, val accuracy: 0.629000
# Loss: 23.556723, Train accuracy: 0.671111, val accuracy: 0.653000
# Loss: 22.889995, Train accuracy: 0.672556, val accuracy: 0.655000
# Loss: 22.294045, Train accuracy: 0.693556, val accuracy: 0.675000

# %% [markdown]
# # Ну что, давайте уже тренировать сеть!

# %% [markdown]
# ## Последний тест - переобучимся (overfit) на маленьком наборе данных
#
# Хороший способ проверить, все ли реализовано корректно - переобучить сеть на маленьком наборе данных.
# Наша модель обладает достаточной мощностью, чтобы приблизить маленький набор данных идеально, поэтому мы ожидаем, что на нем мы быстро дойдем до 100% точности на тренировочном наборе.
#
# Если этого не происходит, то где-то была допущена ошибка!

# %%
data_size = 15
model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-1)
dataset = Dataset(train_X[:data_size], train_y[:data_size], val_X[:data_size], val_y[:data_size])
trainer = Trainer(model, dataset, SGD(), learning_rate=1e-2, num_epochs=150, batch_size=5)

# You should expect this to reach 1.0 training accuracy 
loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 11.559002, Train accuracy: 0.200000, val accuracy: 0.066667
# Loss: 11.520457, Train accuracy: 0.200000, val accuracy: 0.066667
# Loss: 11.493067, Train accuracy: 0.200000, val accuracy: 0.066667
# Loss: 11.473417, Train accuracy: 0.333333, val accuracy: 0.066667
# Loss: 11.444257, Train accuracy: 0.266667, val accuracy: 0.066667
# Loss: 11.412120, Train accuracy: 0.333333, val accuracy: 0.000000
# Loss: 11.396877, Train accuracy: 0.266667, val accuracy: 0.000000
# Loss: 11.359960, Train accuracy: 0.266667, val accuracy: 0.000000
# Loss: 11.339042, Train accuracy: 0.266667, val accuracy: 0.000000
# Loss: 11.302352, Train accuracy: 0.266667, val accuracy: 0.000000
# Loss: 11.258561, Train accuracy: 0.266667, val accuracy: 0.000000
# Loss: 11.206379, Train accuracy: 0.266667, val accuracy: 0.000000
# Loss: 11.154869, Train accuracy: 0.266667, val accuracy: 0.000000
# Loss: 11.034336, Train accuracy: 0.333333, val accuracy: 0.000000
# Loss: 10.896498, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 10.684270, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 10.452036, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 10.175865, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 9.870327, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 9.666652, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 9.257299, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 9.034817, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 8.863988, Train accuracy: 0.333333, val accuracy: 0.000000
# Loss: 8.634762, Train accuracy: 0.333333, val accuracy: 0.000000
# Loss: 8.462136, Train accuracy: 0.333333, val accuracy: 0.000000
# Loss: 8.345042, Train accuracy: 0.333333, val accuracy: 0.000000
# Loss: 8.238580, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 8.192611, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 8.164637, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 8.064320, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 7.967946, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 7.872235, Train accuracy: 0.466667, val accuracy: 0.000000
# Loss: 7.737627, Train accuracy: 0.466667, val accuracy: 0.000000
# Loss: 7.748399, Train accuracy: 0.466667, val accuracy: 0.000000
# Loss: 7.713759, Train accuracy: 0.466667, val accuracy: 0.000000
# Loss: 7.542534, Train accuracy: 0.466667, val accuracy: 0.000000
# Loss: 7.582844, Train accuracy: 0.466667, val accuracy: 0.000000
# Loss: 7.523110, Train accuracy: 0.466667, val accuracy: 0.066667
# Loss: 7.374731, Train accuracy: 0.466667, val accuracy: 0.066667
# Loss: 7.194255, Train accuracy: 0.466667, val accuracy: 0.066667
# Loss: 7.151391, Train accuracy: 0.466667, val accuracy: 0.066667
# Loss: 7.145938, Train accuracy: 0.466667, val accuracy: 0.066667
# Loss: 6.955225, Train accuracy: 0.533333, val accuracy: 0.066667
# Loss: 6.900021, Train accuracy: 0.533333, val accuracy: 0.066667
# Loss: 6.772537, Train accuracy: 0.533333, val accuracy: 0.066667
# Loss: 6.808041, Train accuracy: 0.533333, val accuracy: 0.066667
# Loss: 6.684751, Train accuracy: 0.533333, val accuracy: 0.066667
# Loss: 6.577277, Train accuracy: 0.600000, val accuracy: 0.066667
# Loss: 6.426761, Train accuracy: 0.600000, val accuracy: 0.066667
# Loss: 6.453161, Train accuracy: 0.600000, val accuracy: 0.066667
# Loss: 6.378483, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 6.140435, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 5.988225, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 5.909174, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 5.855176, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 5.741915, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 5.771585, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 5.583969, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 5.525956, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 5.355983, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 5.246423, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 5.194197, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 5.072709, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.913797, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.879452, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.757492, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.734913, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.562852, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.531742, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.482646, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.343939, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.318305, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.264982, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.180055, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.147475, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.119052, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.074170, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 4.035545, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.995233, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.984054, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.903125, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.902906, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.902822, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.840569, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.817445, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.799945, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.759959, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.750896, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.701176, Train accuracy: 0.800000, val accuracy: 0.066667
# Loss: 3.694845, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 3.646439, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 3.620515, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 3.594773, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 3.575477, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 3.539379, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 3.513978, Train accuracy: 0.866667, val accuracy: 0.066667
# Loss: 3.466612, Train accuracy: 0.933333, val accuracy: 0.066667
# Loss: 3.440861, Train accuracy: 0.933333, val accuracy: 0.066667
# Loss: 3.403287, Train accuracy: 0.933333, val accuracy: 0.066667
# Loss: 3.367850, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 3.322300, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 3.273934, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 3.241489, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 3.193682, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 3.146155, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 3.100894, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 3.063539, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.995223, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.952621, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.893795, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.861079, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.800502, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.747237, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.699208, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.653592, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.621308, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.569592, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.525881, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.481216, Train accuracy: 1.000000, val accuracy: 0.066667
# Loss: 2.461179, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.425295, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.384344, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.342465, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.318690, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.290456, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.276729, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.242655, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.225625, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.205955, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.186167, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.174734, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.163205, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.154727, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.139439, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.123444, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.108302, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.101808, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.087265, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.081473, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.069488, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.063986, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.058662, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.051420, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.042689, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.035168, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.029895, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.027563, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.022145, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.015412, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 2.015849, Train accuracy: 1.000000, val accuracy: 0.000000

# %% [markdown]
# Теперь найдем гипепараметры, для которых этот процесс сходится быстрее.
# Если все реализовано корректно, то существуют параметры, при которых процесс сходится в **20** эпох или еще быстрее.
# Найдите их!

# %%
# Now, tweak some hyper parameters and make it train to 1.0 accuracy in 20 epochs or less

model = TwoLayerNet(n_input = train_X.shape[1], n_output = 10, hidden_layer_size = 100, reg = 1e-3)
dataset = Dataset(train_X[:data_size], train_y[:data_size], val_X[:data_size], val_y[:data_size])
# DONE: Change any hyperparamers or optimizators to reach training accuracy in 20 epochs
trainer = Trainer(model, dataset, MomentumSGD(), learning_rate=1e-2, num_epochs=20, batch_size=5)

loss_history, train_history, val_history = trainer.fit()
# Out:
# Loss: 11.513680, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 11.448717, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 11.302025, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 11.173639, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 10.956702, Train accuracy: 0.200000, val accuracy: 0.133333
# Loss: 10.517624, Train accuracy: 0.333333, val accuracy: 0.066667
# Loss: 9.266421, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 8.467875, Train accuracy: 0.400000, val accuracy: 0.000000
# Loss: 8.504277, Train accuracy: 0.400000, val accuracy: 0.066667
# Loss: 7.352184, Train accuracy: 0.533333, val accuracy: 0.066667
# Loss: 6.757181, Train accuracy: 0.466667, val accuracy: 0.000000
# Loss: 6.078379, Train accuracy: 0.666667, val accuracy: 0.066667
# Loss: 5.469034, Train accuracy: 0.600000, val accuracy: 0.066667
# Loss: 4.498352, Train accuracy: 0.733333, val accuracy: 0.000000
# Loss: 3.943004, Train accuracy: 0.733333, val accuracy: 0.066667
# Loss: 2.870564, Train accuracy: 0.800000, val accuracy: 0.000000
# Loss: 2.531349, Train accuracy: 0.800000, val accuracy: 0.000000
# Loss: 2.037058, Train accuracy: 0.933333, val accuracy: 0.000000
# Loss: 1.516824, Train accuracy: 1.000000, val accuracy: 0.000000
# Loss: 1.212617, Train accuracy: 1.000000, val accuracy: 0.000000

# %% [markdown]
# # Итак, основное мероприятие!
#
# Натренируйте лучшую нейросеть! Можно добавлять и изменять параметры, менять количество нейронов в слоях сети и как угодно экспериментировать.
#
# Добейтесь точности лучше **60%** на validation set.

# %%
# Let's train the best one-hidden-layer network we can

data_size = train_X.shape[1]
learning_rate = 1e-4
reg_strength = 5e-1
learning_rate_decay = 0.99
hidden_layer_size = 100
num_epochs = 100
batch_size = 1000

best_classifier = None
best_val_accuracy = None

loss_history = []
train_history = []
val_history = []

model = TwoLayerNet(n_input = data_size, n_output = 10, hidden_layer_size = hidden_layer_size, reg = reg_strength)
dataset = Dataset(train_X[:data_size], train_y[:data_size], val_X[:data_size], val_y[:data_size])
trainer = Trainer(model, dataset, MomentumSGD(), learning_rate=learning_rate , num_epochs=num_epochs, batch_size=batch_size, learning_rate_decay=learning_rate_decay)

loss_history, train_history, val_history = trainer.fit()

# TODO find the best hyperparameters to train the network
# Don't hesitate to add new values to the arrays above, perform experiments, use any tricks you want
# You should expect to get to at least 40% of valudation accuracy
# Save loss/train/history of the best classifier to the variables above

best_val_accuracy = val_history[-1] 
print('best validation accuracy achieved: %f' % best_val_accuracy)
# Out:
# Loss: 1767.011279, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1755.264330, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1740.539681, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1727.181764, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1719.579120, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1716.143023, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1715.392562, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1715.432380, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1715.294418, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1714.887314, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1714.340891, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1713.631649, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1712.864049, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1711.849760, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1710.422214, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1708.222090, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1705.281986, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1701.102473, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1695.455985, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1688.669382, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1680.980349, Train accuracy: 0.194336, val accuracy: 0.206000
# Loss: 1672.161003, Train accuracy: 0.195638, val accuracy: 0.207000
# Loss: 1662.258887, Train accuracy: 0.213216, val accuracy: 0.218000
# Loss: 1650.070173, Train accuracy: 0.232422, val accuracy: 0.225000
# Loss: 1637.282548, Train accuracy: 0.244141, val accuracy: 0.239000
# Loss: 1624.146905, Train accuracy: 0.250651, val accuracy: 0.244000
# Loss: 1610.961949, Train accuracy: 0.265951, val accuracy: 0.270000
# Loss: 1597.273927, Train accuracy: 0.268880, val accuracy: 0.264000
# Loss: 1584.105565, Train accuracy: 0.277344, val accuracy: 0.278000
# Loss: 1569.178936, Train accuracy: 0.279297, val accuracy: 0.274000
# Loss: 1555.140687, Train accuracy: 0.282552, val accuracy: 0.292000
# Loss: 1539.555599, Train accuracy: 0.292318, val accuracy: 0.289000
# Loss: 1523.006540, Train accuracy: 0.304036, val accuracy: 0.313000
# Loss: 1505.387293, Train accuracy: 0.320638, val accuracy: 0.312000
# Loss: 1485.072196, Train accuracy: 0.342122, val accuracy: 0.337000
# Loss: 1462.286253, Train accuracy: 0.347656, val accuracy: 0.342000
# Loss: 1439.333326, Train accuracy: 0.356445, val accuracy: 0.352000
# Loss: 1418.213179, Train accuracy: 0.375000, val accuracy: 0.359000
# Loss: 1393.933065, Train accuracy: 0.368815, val accuracy: 0.363000
# Loss: 1373.691397, Train accuracy: 0.385417, val accuracy: 0.369000
# Loss: 1356.941876, Train accuracy: 0.368164, val accuracy: 0.377000
# Loss: 1346.636080, Train accuracy: 0.386719, val accuracy: 0.374000
# Loss: 1331.072205, Train accuracy: 0.379232, val accuracy: 0.381000
# Loss: 1326.133750, Train accuracy: 0.399740, val accuracy: 0.378000
# Loss: 1304.291403, Train accuracy: 0.388997, val accuracy: 0.402000
# Loss: 1294.825232, Train accuracy: 0.430013, val accuracy: 0.417000
# Loss: 1271.848459, Train accuracy: 0.438802, val accuracy: 0.430000
# Loss: 1249.861374, Train accuracy: 0.480794, val accuracy: 0.446000
# Loss: 1218.905472, Train accuracy: 0.494792, val accuracy: 0.470000
# Loss: 1181.795805, Train accuracy: 0.509115, val accuracy: 0.476000
# Loss: 1151.114007, Train accuracy: 0.513021, val accuracy: 0.487000
# Loss: 1136.269678, Train accuracy: 0.510742, val accuracy: 0.481000
# Loss: 1124.786889, Train accuracy: 0.518880, val accuracy: 0.484000
# Loss: 1113.587621, Train accuracy: 0.531901, val accuracy: 0.496000
# Loss: 1094.006886, Train accuracy: 0.525065, val accuracy: 0.507000
# Loss: 1084.883147, Train accuracy: 0.546875, val accuracy: 0.499000
# Loss: 1079.919367, Train accuracy: 0.539714, val accuracy: 0.517000
# Loss: 1062.795859, Train accuracy: 0.562826, val accuracy: 0.519000
# Loss: 1049.742215, Train accuracy: 0.551432, val accuracy: 0.526000
# Loss: 1035.935352, Train accuracy: 0.574870, val accuracy: 0.525000
# Loss: 1023.877865, Train accuracy: 0.573568, val accuracy: 0.530000
# Loss: 1008.442862, Train accuracy: 0.594727, val accuracy: 0.536000
# Loss: 993.349365, Train accuracy: 0.602865, val accuracy: 0.545000
# Loss: 977.277729, Train accuracy: 0.614583, val accuracy: 0.554000
# Loss: 965.045962, Train accuracy: 0.614258, val accuracy: 0.557000
# Loss: 952.520166, Train accuracy: 0.623698, val accuracy: 0.561000
# Loss: 941.969578, Train accuracy: 0.627930, val accuracy: 0.561000
# Loss: 931.876855, Train accuracy: 0.634115, val accuracy: 0.574000
# Loss: 921.196716, Train accuracy: 0.638997, val accuracy: 0.576000
# Loss: 913.198604, Train accuracy: 0.642253, val accuracy: 0.584000
# Loss: 904.803421, Train accuracy: 0.650716, val accuracy: 0.585000
# Loss: 895.281864, Train accuracy: 0.656901, val accuracy: 0.588000
# Loss: 886.606378, Train accuracy: 0.661133, val accuracy: 0.588000
# Loss: 878.558651, Train accuracy: 0.668294, val accuracy: 0.588000
# Loss: 871.124256, Train accuracy: 0.667643, val accuracy: 0.598000
# Loss: 863.263471, Train accuracy: 0.675456, val accuracy: 0.598000
# Loss: 855.359375, Train accuracy: 0.678060, val accuracy: 0.594000
# Loss: 849.034872, Train accuracy: 0.681315, val accuracy: 0.598000
# Loss: 842.551766, Train accuracy: 0.687500, val accuracy: 0.602000
# Loss: 834.237185, Train accuracy: 0.689128, val accuracy: 0.606000
# Loss: 827.286332, Train accuracy: 0.693359, val accuracy: 0.609000
# Loss: 821.354956, Train accuracy: 0.699544, val accuracy: 0.607000
# Loss: 815.318057, Train accuracy: 0.697591, val accuracy: 0.610000
# Loss: 808.809463, Train accuracy: 0.705729, val accuracy: 0.613000
# Loss: 802.615937, Train accuracy: 0.708333, val accuracy: 0.617000
# Loss: 796.008845, Train accuracy: 0.710938, val accuracy: 0.618000
# Loss: 790.461463, Train accuracy: 0.715495, val accuracy: 0.621000
# Loss: 784.440017, Train accuracy: 0.719076, val accuracy: 0.625000
# Loss: 778.327000, Train accuracy: 0.721354, val accuracy: 0.628000
# Loss: 773.091939, Train accuracy: 0.725911, val accuracy: 0.636000
# Loss: 767.099361, Train accuracy: 0.726562, val accuracy: 0.639000
# Loss: 762.409403, Train accuracy: 0.727539, val accuracy: 0.637000
# Loss: 757.928636, Train accuracy: 0.732096, val accuracy: 0.642000
# Loss: 752.140671, Train accuracy: 0.732096, val accuracy: 0.641000
# Loss: 746.906070, Train accuracy: 0.737630, val accuracy: 0.644000
# Loss: 741.730300, Train accuracy: 0.739909, val accuracy: 0.646000
# Loss: 736.725600, Train accuracy: 0.743815, val accuracy: 0.650000
# Loss: 732.341077, Train accuracy: 0.746419, val accuracy: 0.649000
# Loss: 728.942298, Train accuracy: 0.746094, val accuracy: 0.651000
# Loss: 724.193267, Train accuracy: 0.749349, val accuracy: 0.653000
# best validation accuracy achieved: 0.653000

# %%
plt.figure(figsize=(15, 7))
plt.subplot(211)
plt.title("Loss")
plt.plot(loss_history)
plt.subplot(212)
plt.title("Train/validation accuracy")
plt.plot(train_history)
plt.plot(val_history)

# %% [markdown]
# # Как обычно, посмотрим, как наша лучшая модель работает на тестовых данных

# %%
best_classifier=model
test_pred = best_classifier.predict(test_X)
test_accuracy = multiclass_accuracy(test_pred, test_y)
print('Neural net test set accuracy: %f' % (test_accuracy, ))
# Out:
# Neural net test set accuracy: 0.613000
